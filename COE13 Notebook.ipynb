# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# load data
center_attendance_pandas = pd.read_csv("Traffic.csv",
                                       index_col="id") # use the column named _id as the row index

# %%
d = center_attendance_pandas['neighborhood'].value_counts()

# %%
d
# Out:
# Squirrel Hill South    28
# Bloomfield             21
# Shadyside              18
# Highland Park          16
# East Liberty           16
#                        ..
# Allegheny Center        1
# Upper Lawrenceville     1
# Duquesne Heights        1
# Regent Square           1
# Crawford-Roberts        1
# Name: neighborhood, Length: 74, dtype: int64

# %%
plt.figure();
d.plot.pie(figsize=(12, 12));
